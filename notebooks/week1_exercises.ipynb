# %% [markdown]
# # Week 1 — Exercises
#
# This notebook contains starter templates for the Week 1 homework. Fill in the `# TODO` parts, run the cells, and save your completed notebook as `notebooks/week1_exercises.ipynb` before submitting.
#
# ## Exercise 1 — Initials
# Write a program that asks for a user's full name (first and last name) and prints the initials in the format `J.D.` for `John Doe`.

# %% [markdown]
# ## Exercise 2 — Simple calculator
# Create a small calculator that asks the user for two numbers and prints their sum, difference, product, and quotient. Handle division by zero gracefully.

# %% [markdown]
# ## Exercise 3 — Greeting variations
# Ask the user for their name and whether they prefer a formal greeting. If they choose formal (`y`), print `Good day, <Name>.` Otherwise print `Hi <Name>!`.

# %% [markdown]
# ## Exercise 4 — Save answers (optional)
# Save your outputs or small results to a text file called `output_week1.txt` inside the `data/` folder. This is optional but useful to practice file I/O.

# %%
def save_output(filename='data/output_week1.txt'):
    content = []
    name = input('Name to save: ')
    content.append(f'Name: {name}')
    try:
        with open(filename, 'w', encoding='utf-8') as f:
            f.write('\n'.join(content))
        print('Saved to', filename)
    except Exception as e:
        print('Error saving file:', e)

# Un-comment to run
# save_output()

# %% [markdown]
# ## Submission
# Save this notebook as `notebooks/week1_exercises.ipynb`. You may also submit `.py` scripts under `src/` with the same functionality. Make sure your code is properly commented and includes brief explanations for each function.
